# %% [markdown]
# # **Módulo 05** | Python: Programação Funcional
#
# 0. Preparação do ambiente
#
# Neste exercício vamos trabalhar com o arquivo csv com dados de crédito, definido abaixo. Execute cada uma das células de código para escrever os arquivos na sua máquina virtual.

# %%
# %%writefile credito.csv
# id_vendedor,valor_emprestimos,quantidade_emprestimos,data
# 104271,448.0,1,20161208
# 21476,826.7,3,20161208
# 87440,313.6,3,20161208
# 15980,-8008.0,6,20161208
# 215906,2212.0,5,20161208
# 33696,2771.3,2,20161208
# 33893,2240.0,3,20161208
# 214946,-4151.0,18,20161208
# 123974,2021.95,2,20161208
# 225870,4039.0,2,20161208
# Out:
# Overwriting credito.csv

# %% [markdown]
# Vamos ler o conteúdo do arquivo em uma lista onde cada elemento é um dicionário representando as linhas do arquivo.

# %%
emprestimos = []
with open (file = './credito.csv', mode = 'r', encoding = 'utf8') as fp:
  fp.readline() #leitura do cabeçalho
  linha = fp.readline()
  while linha:
    linha_emprestimo = {}
    linha_elementos = linha.strip().split(sep = ',')
    linha_emprestimo['id_vendedor'] = linha_elementos[0]
    linha_emprestimo['valor_emprestimos'] = linha_elementos[1]
    linha_emprestimo['quantidade_emprestimos'] = linha_elementos[2]
    linha_emprestimo['data'] = linha_elementos[3]
    emprestimos.append(linha_emprestimo)
    linha = fp.readline()

for emprestimo in emprestimos:
  print(emprestimo)
# Out:
# {'id_vendedor': '104271', 'valor_emprestimos': '448.0', 'quantidade_emprestimos': '1', 'data': '20161208'}
# {'id_vendedor': '21476', 'valor_emprestimos': '826.7', 'quantidade_emprestimos': '3', 'data': '20161208'}
# {'id_vendedor': '87440', 'valor_emprestimos': '313.6', 'quantidade_emprestimos': '3', 'data': '20161208'}
# {'id_vendedor': '15980', 'valor_emprestimos': '-8008.0', 'quantidade_emprestimos': '6', 'data': '20161208'}
# {'id_vendedor': '215906', 'valor_emprestimos': '2212.0', 'quantidade_emprestimos': '5', 'data': '20161208'}
# {'id_vendedor': '33696', 'valor_emprestimos': '2771.3', 'quantidade_emprestimos': '2', 'data': '20161208'}
# {'id_vendedor': '33893', 'valor_emprestimos': '2240.0', 'quantidade_emprestimos': '3', 'data': '20161208'}
# {'id_vendedor': '214946', 'valor_emprestimos': '-4151.0', 'quantidade_emprestimos': '18', 'data': '20161208'}
# {'id_vendedor': '123974', 'valor_emprestimos': '2021.95', 'quantidade_emprestimos': '2', 'data': '20161208'}
# ...

# %% [markdown]
# ## 1\. Função `map`
# Aplique a função map na lista de `emprestimos` para extrair os valores da chave `valor_emprestimos` na lista `valor_emprestimos_lista`. Faça também a conversão de `str` para `float`.

# %%
valor_emprestimos_lista = []

# %%
#for emprestimo in emprestimos:
valor_emprestimos_lista = list(map(lambda emprestimo: float(emprestimo['valor_emprestimos']), emprestimos))

print(valor_emprestimos_lista)
# Out:
# [448.0, 826.7, 313.6, -8008.0, 2212.0, 2771.3, 2240.0, -4151.0, 2021.95, 4039.0]

# %% [markdown]
# ## 2\. Função `filter`
#
# Aplique a função filter na lista de `valor_emprestimos_lista` para filtrar apenas os valores maiores que zero (os valores negativas são erros na base de dados). Salve os valores na lista `valor_emprestimos_lista_filtrada`.

# %%
valor_emprestimos_lista_filtrada = []

# %%
valor_emprestimos_lista_filtrada = list(filter(lambda num: num > 0, valor_emprestimos_lista))
print(valor_emprestimos_lista_filtrada)
# Out:
# [448.0, 826.7, 313.6, 2212.0, 2771.3, 2240.0, 2021.95, 4039.0]

# %% [markdown]
# ## 3\. Função `reduce`
#
# Com a nossa lista de valores de emprestimo pronta, vamos extrair algumas métricas.
# ### 3\.1\. Função `reduce` para extrair a **soma**
# Aplique a função reduce para somar os elementos da lista `valor_emprestimos_lista_filtrada` na variavel `soma_valor_emprestimos`.

# %%
from functools import reduce

soma_valor_emprestimos = reduce(lambda x, y: x + y, valor_emprestimos_lista_filtrada)
print(soma_valor_emprestimos)
# Out:
# 14872.550000000001

# %% [markdown]
# ### 3\.2\. Função `reduce` para extrair a **media aritimética**
#
# Aplique a função reduce para extrair a média aritimética (mais informações [aqui](https://pt.wikipedia.org/wiki/M%C3%A9dia#M%C3%A9dia_aritm%C3%A9tica)) dos elementos da lista `valor_emprestimos_lista_filtrada` na variavel `media_valor_emprestimos`.
#
# Dica: Para calcular o tamanho da lista, isto é a quantidade de elementos, utilize a função len(), dentro do argumento da função coloque a lista `valor_emprestimos_lista_filtrada`.

# %%
from functools import reduce

soma_valor_emprestimos = reduce(lambda x, y: x + y, valor_emprestimos_lista_filtrada)
print(soma_valor_emprestimos)

n = len(valor_emprestimos_lista_filtrada)
print(n)

media_valor_emprestimos = soma_valor_emprestimos / n 
print(media_valor_emprestimos)
# Out:
# 14872.550000000001
# 8
# 1859.0687500000001

# %% [markdown]
# ### 3\.3\. (**Desafio**) Função `reduce` para extrair o **desvio padrão amostral**
#
# Aplique a função reduce para extrair o **desvio padrão amostral** (mais informações [aqui](https://pt.wikipedia.org/wiki/Desvio_padr%C3%A3o)) dos elementos da lista `valor_emprestimos_lista_filtrada` na variavel `desvio_padrao_valor_emprestimos`.
#
#
# **Arquivo em anexo Word**
#
# (Desafio) Função reduce para extrair o desvio padrão
#
# Utilize os seguintes passos para a solução do desafio:
#
# 1)	Usar a função 'map' para fazer a subtração de cada elemento de 'valor_emprestimos_lista_filtrada' pela média dos valores e elevar essa diferença ao quadrado.
# Dica: x: elementos de 'valor_emprestimos_lista_filtrada'
# media_valor_emprestimos: média dos valores 'valor_emprestimos_lista_filtrada'
# Diferença da média de cada elemento elevado ao quadrado: (x - media_valor_emprestimos)**2

# %%
diferencas = []
for x in valor_emprestimos_lista_filtrada:
  diferencas = list(map(lambda x: (x - media_valor_emprestimos)**2, valor_emprestimos_lista_filtrada))

print(diferencas)
# Out:
# [1991115.0172265628, 1065785.2359765626, 2388473.6572265625, 124560.46722656241, 832165.8534765625, 145108.6172265624, 26530.30160156247, 4752100.254726561]

# %% [markdown]
# 2)	Usar a função 'reduce' para somar os valores obtidos no passo 1)

# %%
from functools import reduce

soma_diferencas = reduce(lambda x, y: x + y, diferencas)
print(soma_diferencas)
# Out:
# 11325839.404687498

# %% [markdown]
# 3)	Converter os valores obtidos no passo 2) para o tipo 'float'

# %%
diferencas = []
for x in valor_emprestimos_lista_filtrada:
  diferencas = list(map(lambda x: float((x - media_valor_emprestimos)**2), valor_emprestimos_lista_filtrada))

print(diferencas)
# Out:
# [1991115.0172265628, 1065785.2359765626, 2388473.6572265625, 124560.46722656241, 832165.8534765625, 145108.6172265624, 26530.30160156247, 4752100.254726561]

# %% [markdown]
# 4)	Dividir o resultado do passo 3) por 'len(valor_emprestimos_lista_filtrada) - 1'

# %%
from functools import reduce

soma_diferencas = reduce(lambda x, y: x + y, diferencas)
print(soma_diferencas)

media_diferencas = soma_diferencas / (len(valor_emprestimos_lista_filtrada) -1)
print(media_diferencas)
# Out:
# 11325839.404687498
# 1617977.0578124996

# %% [markdown]
# 5)	Ao final, vai extrair a raiz quadrada do resultada de todo esse processo. Para a extração, utilize a seguinte função:
#
# Função 'sqrt()': para usar, importe a função (mostrado abaixo), depois use o comando 'sqrt()' colocando o valor que você deseja extrair a raiz quadrada dentro do argumento da função. Exemplo: extrair a raiz quadrada de 'x': sqrt(x)
#
# from math import sqrt

# %%
from math import sqrt

desvio_padrao_amostral_emprestimos = sqrt(media_diferencas)
print(desvio_padrao_amostral_emprestimos)
# Out:
# 1271.9972711497849
