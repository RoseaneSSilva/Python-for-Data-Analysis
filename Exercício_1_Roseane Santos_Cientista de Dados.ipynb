# %%
print('Olá mundo!')
# Out:
# Olá mundo!

# %% [markdown]
# ![2022-10-12 (1).png](data:image/png;base64,...)

# %%
# (A)
A = 320.52 * 3
print(A)

# (B)

B = 834.47 / 119.21
print(B)

# (C)
C = 15378.12 / 5
print(C)
# Out:
# 961.56
# 7.000000000000001
# 3075.6240000000003

# %%
cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.'
print(cancao.upper())
print(cancao.find('gigante'))
print(cancao.title())
# Out:
# RODA MUNDO, RODA GIGANTE, RODA MOINHO, RODA PIÃO.
# 17
# Roda Mundo, Roda Gigante, Roda Moinho, Roda Pião.

# %%
noticia = 'Selic vai a 2,75% e supera expectativas; ' + \
 'é a primeira alta em 6 anos.'
busca_taxa = noticia.find('2')
print(busca_taxa)
selic = noticia[12 : busca_taxa + 5]
print(selic)

busca_ano = noticia.find('6')
print(busca_ano)
ano = noticia[62]
print(ano)
# Out:
# 12
# 2,75%
# 62
# 6

# %%
a = False
b = True
x = not a & b

y = not a 
print(y)

x = y & b 
print(x)
# Out:
# True
# True
